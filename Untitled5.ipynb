# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
from IPython.display import display,clear_output
import time
from PIL import Image

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Open webcam
cap = cv2.VideoCapture(0)

print("Camera started...")
print("Capturing frame in 5 seconds...")

# Wait for 5 seconds
time.sleep(10)

# Capture a single frame
ret, frame = cap.read()

if ret:
    # Perform object detection
    results = model(frame)

    # Draw bounding boxes and labels
    annotated_frame = results[0].plot()

    img=cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)
    # Display the detected frame
    #clear_output(wait=True)
    #plt.figure(figsize=(8,6))
    #plt.imshow(img)
    #plt.axis("off")
    #plt.title("YOLOv8 Object Detection")
    #plt.show()
    display(Image.fromarray(img))
else:
    print("Failed to capture frame.")

# Release webcam
cap.release()
# Out:
# Camera started...
# Capturing frame in 5 seconds...
#
# 0: 480x640 1 person, 2 cell phones, 108.9ms
# Speed: 4.4ms preprocess, 108.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=160x120>
